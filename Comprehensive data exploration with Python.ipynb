# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import pickle
from scipy.stats import chisquare
from scipy import stats

# %% [markdown]
# ## Get to know about the data

# %%
# Import the data into Pandas dataframe

df = pd.read_csv("bank-additional-full.csv", sep=';')

# %%
# Check the first 5 rows

df.head()
# Out:
#    age        job  marital    education  default housing loan    contact  \
# 0   56  housemaid  married     basic.4y       no      no   no  telephone
# 1   57   services  married  high.school  unknown      no   no  telephone
# 2   37   services  married  high.school       no     yes   no  telephone
# 3   40     admin.  married     basic.6y       no      no   no  telephone
# 4   56   services  married  high.school       no      no  yes  telephone
#
#   month day_of_week ...  campaign  pdays  previous     poutcome emp.var.rate  \
# 0   may         mon ...         1    999         0  nonexistent          1.1
# 1   may         mon ...         1    999         0  nonexistent          1.1
# 2   may         mon ...         1    999         0  nonexistent          1.1
# 3   may         mon ...         1    999         0  nonexistent          1.1
# 4   may         mon ...         1    999         0  nonexistent          1.1
#
#    cons.price.idx  cons.conf.idx  euribor3m  nr.employed   y
# 0          93.994          -36.4      4.857       5191.0  no
# 1          93.994          -36.4      4.857       5191.0  no
# 2          93.994          -36.4      4.857       5191.0  no
# 3          93.994          -36.4      4.857       5191.0  no
# 4          93.994          -36.4      4.857       5191.0  no
#
# [5 rows x 21 columns]

# %%
# Check the number of row and column

df.shape
# Out:
# (41188, 21)

# %%
# Check the name and data type of each column

df.dtypes
# Out:
# age                 int64
# job                object
# marital            object
# education          object
# default            object
# housing            object
# loan               object
# contact            object
# month              object
# day_of_week        object
# duration            int64
# campaign            int64
# pdays               int64
# previous            int64
# poutcome           object
# emp.var.rate      float64
# cons.price.idx    float64
# cons.conf.idx     float64
# euribor3m         float64
# nr.employed       float64
# y                  object
# dtype: object

# %%
# Check missing values
def num_missing(x):
    return sum(x.isnull())

#Apply per column

print ("Missing values per column:")
print (df.apply(num_missing, axis=0))
# Out:
# Missing values per column:
# age               0
# job               0
# marital           0
# education         0
# default           0
# housing           0
# loan              0
# contact           0
# month             0
# day_of_week       0
# duration          0
# campaign          0
# pdays             0
# previous          0
# poutcome          0
# emp.var.rate      0
# cons.price.idx    0
# cons.conf.idx     0
# euribor3m         0
# nr.employed       0
# y                 0
# dtype: int64

# %% [markdown]
# ## Change variable names

# %%
# Make the variable names more descriptive
df=df.rename(columns = {'housing':'housingLoan'})
df=df.rename(columns = {'loan':'personalLoan'})
df=df.rename(columns = {'contact':'contactMethod'})
df=df.rename(columns = {'month':'lastContact_month'})
df=df.rename(columns = {'day_of_week':'lastContact_day'})
df=df.rename(columns = {'duration':'lastContact_duration'})
df=df.rename(columns = {'campaign':'numberOfContact'})
df=df.rename(columns = {'pdays':'pastCam_daysSince'})
df=df.rename(columns = {'previous':'pastCam_numberOfContact'})
df=df.rename(columns = {'poutcome':'pastCam_result'})
df=df.rename(columns = {'y':'subscribe'})
df=df.rename(columns = {'emp.var.rate':'idx_employment'})
df=df.rename(columns = {'cons.price.idx':'idx_price'})
df=df.rename(columns = {'cons.conf.idx':'idx_confidence'})
df=df.rename(columns = {'euribor3m':'idx_euribor'})
df=df.rename(columns = {'nr.employed':'idx_employeesNum'})

# %% [markdown]
# ## Look into each variable and wrangle the data

# %% [markdown]
# ### 1. subscribe (response variable)

# %%
# Check the distribution of values 

df.subscribe.value_counts()
# Out:
# no     36548
# yes     4640
# Name: subscribe, dtype: int64

# %% [markdown]
# * The variable subscribe doesn't have any missing nor illogical values

# %%
# Transform the level names for easier processing

df['subscribe'] = df['subscribe'].map({'yes': 1, 'no': 0})

# %% [markdown]
# ### 2. age

# %%
# Check the distribution of values 

df.age.describe()
# Out:
# count    41188.00000
# mean        40.02406
# std         10.42125
# min         17.00000
# 25%         32.00000
# 50%         38.00000
# 75%         47.00000
# max         98.00000
# Name: age, dtype: float64

# %%
# Plot the distribution of values 

fig = plt.figure(1, figsize=(3, 6))
df.boxplot(column="age")
plt.show()

# %% [markdown]
# * The variable age doesn't have any missing nor illogical values ranging from 17 to 98

# %% [markdown]
# ### 3. job

# %%
# Check the distribution of values 

df.job.value_counts()
# Out:
# admin.           10422
# blue-collar       9254
# technician        6743
# services          3969
# management        2924
# retired           1720
# entrepreneur      1456
# self-employed     1421
# housemaid         1060
# unemployed        1014
# student            875
# unknown            330
# Name: job, dtype: int64

# %% [markdown]
# * There are 'unknown' levels in the variable job.
# * To decide whether to leave unknown as is or replace with other value, we ran chi-square test of independence to see whether the two variables, job and subscribe (response variable), are independent for the level 'unknown' and the rest of levels.

# %%
# Create a dataframe with two variables 

df_job = df[['subscribe', 'job']]

# Change the level name

df_job.loc[df_job.job != 'unknown', 'job'] = 'known'

# Create a crosstab 

observed_job = pd.crosstab(df_job.subscribe, df_job.job, margins=False)
observed_job
# Out:
# job        known  unknown
# subscribe
# 0          36255      293
# 1           4603       37

# %%
# Run chi-square test 

stats.chi2_contingency(observed_job) 

# The output below shows the chi-square statistic, the p-value and the degrees of freedom 
# followed by the expected counts
# Out:
# (0.0032104107038062905,
#  0.95481565081367703,
#  1,
#  array([[ 36255.17587647,    292.82412353],
#         [  4602.82412353,     37.17587647]]))

# %% [markdown]
# - Given the high p-value, the test result does not detect a significant relationship between the variables.
# - It means that there is no specific pattern in missingness (unknown)
# - Therefore, we imputed the unknown with the mode.

# %%
# Replace unknown with mode

df.loc[df.job == 'unknown', 'job'] = 'admin.'

# %% [markdown]
# ### 4. marital

# %%
# Check the distribution of values 

df.marital.value_counts()
# Out:
# married     24928
# single      11568
# divorced     4612
# unknown        80
# Name: marital, dtype: int64

# %% [markdown]
# - There are 'unknown' levels in the variable job.
# - To decide whether to leave unknown as is or replace with other value, we ran chi-square test of independence

# %%
# Create a dataframe with two variables 

df_marital = df[['subscribe', 'marital']]

# Change the level name

df_marital.loc[df_marital.marital != 'unknown', 'marital'] = 'known'

# Create a crosstab 

observed_marital = pd.crosstab(df_marital.subscribe, df_marital.marital, margins=False)
observed_marital
# Out:
# marital    known  unknown
# subscribe
# 0          36480       68
# 1           4628       12

# %%
# Run chi-square test 

stats.chi2_contingency(observed_marital) 

# The output below shows the chi-square statistic, the p-value and the degrees of freedom 
# followed by the expected counts
# Out:
# (0.77535114047986342,
#  0.37856670795812708,
#  1,
#  array([[  3.64770123e+04,   7.09876663e+01],
#         [  4.63098767e+03,   9.01233369e+00]]))

# %% [markdown]
# - Given the high p-value, the test result does not detect a significant relationship between the variables.
# - It means that there is no specific pattern in missingness (unknown)
# - Therefore, we imputed the unknown with the mode.

# %%
# Replace unknown with mode

df.loc[df.marital == 'unknown', 'marital'] = 'married'

# %% [markdown]
# ### 5. education

# %%
# Check the distribution of values 

df.education.value_counts()
# Out:
# university.degree      12168
# high.school             9515
# basic.9y                6045
# professional.course     5243
# basic.4y                4176
# basic.6y                2292
# unknown                 1731
# illiterate                18
# Name: education, dtype: int64

# %% [markdown]
# - There are 'unknown' levels in the variable job.
# - To decide whether to leave unknown as is or replace with other value, we ran chi-square test of independence

# %%
# Create a dataframe with two variables 

df_education = df[['subscribe', 'education']]

# Change the level name

df_education.loc[df_education.education != 'unknown', 'education'] = 'known'

# Create a crosstab 

observed_education = pd.crosstab(df_education.subscribe, df_education.education, margins=False)
observed_education
# Out:
# education  known  unknown
# subscribe
# 0          35068     1480
# 1           4389      251

# %%
# Run chi-square test 

stats.chi2_contingency(observed_education) 

# The output below shows the chi-square statistic, the p-value and the degrees of freedom 
# followed by the expected counts
# Out:
# (18.579197631494843,
#  1.6298947683080677e-05,
#  1,
#  array([[ 35012.0043702,   1535.9956298],
#         [  4444.9956298,    195.0043702]]))

# %% [markdown]
# - Given the low p-value (<0.01), the test result demonstrates a significant relationship between the variables.
# - It means that there is specific pattern in missingness (unknown)
# - Therefore, we decided to maintain the unknown level

# %% [markdown]
# ### 6. default

# %%
# Check the distribution of values 

df.default.value_counts()
# Out:
# no         32588
# unknown     8597
# yes            3
# Name: default, dtype: int64

# %% [markdown]
# - There are 'unknown' levels in the variable job.
# - To decide whether to leave unknown as is or replace with other value, we ran chi-square test of independence

# %%
# Create a dataframe with two variables 

df_default = df[['subscribe', 'default']]

# Change the level name

df_default.loc[df_default.default != 'unknown', 'default'] = 'known'

# Create a crosstab 

observed_default = pd.crosstab(df_default.subscribe, df_default.default, margins=False)
observed_default
# Out:
# default    known  unknown
# subscribe
# 0          28394     8154
# 1           4197      443

# %%
# Run chi-square test 

stats.chi2_contingency(observed_default) 

# The output below shows the chi-square statistic, the p-value and the degrees of freedom 
# followed by the expected counts
# Out:
# (405.30737395058429,
#  3.8512776525099627e-90,
#  1,
#  array([[ 28919.4879091,   7628.5120909],
#         [  3671.5120909,    968.4879091]]))

# %% [markdown]
# - Given the low p-value (<0.01), the test result demonstrates a significant relationship between the variables.
# - It means that there is specific pattern in missingness (unknown)
# - Therefore, we decided to maintain the unknown level

# %% [markdown]
# ### 7. housingLoan

# %%
# Check the distribution of values 

df.housingLoan.value_counts()
# Out:
# yes        21576
# no         18622
# unknown      990
# Name: housingLoan, dtype: int64

# %% [markdown]
# - There are 'unknown' levels in the variable job.
# - To decide whether to leave unknown as is or replace with other value, we ran chi-square test of independence

# %%
# Create a dataframe with two variables 

df_housingLoan = df[['subscribe', 'housingLoan']]

# Change the level name

df_housingLoan.loc[df_housingLoan.housingLoan != 'unknown', 'housingLoan'] = 'known'

# Create a crosstab 

observed_housingLoan = pd.crosstab(df_housingLoan.subscribe, df_housingLoan.housingLoan, margins=False)
observed_housingLoan
# Out:
# housingLoan  known  unknown
# subscribe
# 0            35665      883
# 1             4533      107

# %%
# Run chi-square test 

stats.chi2_contingency(observed_housingLoan) 

# The output below shows the chi-square statistic, the p-value and the degrees of freedom 
# followed by the expected counts
# Out:
# (0.16795381809777024,
#  0.68193675355130423,
#  1,
#  array([[ 35669.52762941,    878.47237059],
#         [  4528.47237059,    111.52762941]]))

# %% [markdown]
# - Given the high p-value, the test result does not detect a significant relationship between the variables.
# - It means that there is no specific pattern in missingness (unknown)
# - Therefore, we imputed the unknown with the mode.

# %%
# Replace unknown with mode

df.loc[df.housingLoan == 'unknown', 'housingLoan'] = 'yes'

# %% [markdown]
# ### 8. personalLoan

# %%
# Check the distribution of values 

df.personalLoan.value_counts()
# Out:
# no         33950
# yes         6248
# unknown      990
# Name: personalLoan, dtype: int64

# %% [markdown]
# - There are 'unknown' levels in the variable job.
# - To decide whether to leave unknown as is or replace with other value, we ran chi-square test of independence

# %%
# Create a dataframe with two variables 

df_loan = df[['subscribe', 'personalLoan']]

# Change the level name

df_loan.loc[df_loan.personalLoan != 'unknown', 'personalLoan'] = 'known'

# Create a crosstab 

observed_loan = pd.crosstab(df_loan.subscribe, df_loan.personalLoan, margins=False)
observed_loan
# Out:
# personalLoan  known  unknown
# subscribe
# 0             35665      883
# 1              4533      107

# %%
# Run chi-square test 

stats.chi2_contingency(observed_loan) 

# The output below shows the chi-square statistic, the p-value and the degrees of freedom 
# followed by the expected counts
# Out:
# (0.16795381809777024,
#  0.68193675355130423,
#  1,
#  array([[ 35669.52762941,    878.47237059],
#         [  4528.47237059,    111.52762941]]))

# %% [markdown]
# - Given the high p-value, the test result does not detect a significant relationship between the variables.
# - It means that there is no specific pattern in missingness (unknown)
# - Therefore, we imputed the unknown with the mode.

# %%
# Replace unknown with mode

df.loc[df.personalLoan == 'unknown', 'personalLoan'] = 'no'

# %% [markdown]
# ### 9. contactMethod

# %%
# Check the distribution of values 

df.contactMethod.value_counts()
# Out:
# cellular     26144
# telephone    15044
# Name: contactMethod, dtype: int64

# %% [markdown]
# - The variable contactMethod doesn't have any missing nor illogical level.

# %% [markdown]
# ### 10. lastContact_month

# %%
# Check the distribution of values 

df.lastContact_month.value_counts()
# Out:
# may    13769
# jul     7174
# aug     6178
# jun     5318
# nov     4101
# apr     2632
# oct      718
# sep      570
# mar      546
# dec      182
# Name: lastContact_month, dtype: int64

# %% [markdown]
# - The variable lastContact_month doesn't have any missing nor illogical level.

# %% [markdown]
# ### 11. lastContact_day

# %%
# Check the distribution of values 

df.lastContact_day.value_counts()
# Out:
# thu    8623
# mon    8514
# wed    8134
# tue    8090
# fri    7827
# Name: lastContact_day, dtype: int64

# %% [markdown]
# - The variable lastContact_month doesn't have any missing nor illogical level.

# %% [markdown]
# ### 12. lastContact_duration

# %%
# Check the distribution of values 

df.lastContact_duration.describe()
# Out:
# count    41188.000000
# mean       258.285010
# std        259.279249
# min          0.000000
# 25%        102.000000
# 50%        180.000000
# 75%        319.000000
# max       4918.000000
# Name: lastContact_duration, dtype: float64

# %%
# Plot the distribution of values 

fig = plt.figure(1, figsize=(3, 6))
df.boxplot(column="lastContact_duration")
plt.show()

# %% [markdown]
# ### 13. numberOfContact

# %%
# Check the distribution of values 

df.numberOfContact.describe()
# Out:
# count    41188.000000
# mean         2.567593
# std          2.770014
# min          1.000000
# 25%          1.000000
# 50%          2.000000
# 75%          3.000000
# max         56.000000
# Name: numberOfContact, dtype: float64

# %%
# Check the distribution of values 

df.numberOfContact.value_counts().head(10)
# Out:
# 1     17642
# 2     10570
# 3      5341
# 4      2651
# 5      1599
# 6       979
# 7       629
# 8       400
# 9       283
# 10      225
# Name: numberOfContact, dtype: int64

# %%
# Plot the distribution of values 

fig = plt.figure(1, figsize=(3, 6))
df.boxplot(column="numberOfContact")
plt.show()

# %% [markdown]
# ### 14. pastCam_daysSince

# %%
# Check the distribution of values 

df.pastCam_daysSince.describe()
# Out:
# count    41188.000000
# mean       962.475454
# std        186.910907
# min          0.000000
# 25%        999.000000
# 50%        999.000000
# 75%        999.000000
# max        999.000000
# Name: pastCam_daysSince, dtype: float64

# %%
# Check the distribution of values 

df.pastCam_daysSince.value_counts()
# Out:
# 999    39673
# 3        439
# 6        412
# 4        118
# 9         64
# 2         61
# 7         60
# 12        58
# 10        52
# 5         46
# 13        36
# 11        28
# 1         26
# 15        24
# 14        20
# 8         18
# 0         15
# 16        11
# 17         8
# 18         7
# 19         3
# 22         3
# 21         2
# 26         1
# 20         1
# 25         1
# 27         1
# Name: pastCam_daysSince, dtype: int64

# %% [markdown]
# ### 15. pastCam_numberOfContact

# %%
# Check the distribution of values 

df.pastCam_numberOfContact.describe()
# Out:
# count    41188.000000
# mean         0.172963
# std          0.494901
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          0.000000
# max          7.000000
# Name: pastCam_numberOfContact, dtype: float64

# %%
# Check the distribution of values 

df.pastCam_numberOfContact.value_counts()
# Out:
# 0    35563
# 1     4561
# 2      754
# 3      216
# 4       70
# 5       18
# 6        5
# 7        1
# Name: pastCam_numberOfContact, dtype: int64

# %% [markdown]
# ### 16. pastCam_result

# %%
# Check the distribution of values 

df.pastCam_result.value_counts()
# Out:
# nonexistent    35563
# failure         4252
# success         1373
# Name: pastCam_result, dtype: int64

# %% [markdown]
# - The variable pastCam_result doesn't have any missing nor illogical values

# %% [markdown]
# ### 17. idx_employment

# %%
# Check the distribution of values 

df.idx_employment.describe()
# Out:
# count    41188.000000
# mean         0.081886
# std          1.570960
# min         -3.400000
# 25%         -1.800000
# 50%          1.100000
# 75%          1.400000
# max          1.400000
# Name: idx_employment, dtype: float64

# %% [markdown]
# - The variable idx_employment doesn't have any missing nor illogical values ranging from 0.08 to 1.4

# %% [markdown]
# ### 18. idx_price

# %%
# Check the distribution of values 

df.idx_price.describe()
# Out:
# count    41188.000000
# mean        93.575664
# std          0.578840
# min         92.201000
# 25%         93.075000
# 50%         93.749000
# 75%         93.994000
# max         94.767000
# Name: idx_price, dtype: float64

# %% [markdown]
# - The variable idx_confidence doesn't have any missing nor illogical values ranging from 93.58 to 94.77

# %% [markdown]
# ### 19. idx_confidence

# %%
# Check the distribution of values 

df.idx_confidence.describe()
# Out:
# count    41188.000000
# mean       -40.502600
# std          4.628198
# min        -50.800000
# 25%        -42.700000
# 50%        -41.800000
# 75%        -36.400000
# max        -26.900000
# Name: idx_confidence, dtype: float64

# %% [markdown]
# - The variable idx_confidence doesn't have any missing nor illogical values ranging from -50.8 to -26.9

# %% [markdown]
# ### 20. idx_euribor

# %%
# Check the distribution of values 

df.idx_euribor.describe()
# Out:
# count    41188.000000
# mean         3.621291
# std          1.734447
# min          0.634000
# 25%          1.344000
# 50%          4.857000
# 75%          4.961000
# max          5.045000
# Name: idx_euribor, dtype: float64

# %% [markdown]
# - The variable idx_euribor doesn't have any missing nor illogical values ranging from 0.63 to 5.04

# %% [markdown]
# ### 21. idx_employeesNum

# %%
# Check the distribution of values 

df.idx_employeesNum.describe()
# Out:
# count    41188.000000
# mean      5167.035911
# std         72.251528
# min       4963.600000
# 25%       5099.100000
# 50%       5191.000000
# 75%       5228.100000
# max       5228.100000
# Name: idx_employeesNum, dtype: float64

# %% [markdown]
# - The variable idx_employeesNum doesn't have any missing nor illogical values ranging from 4963.6 to 5228

# %% [markdown]
# ## Export and import wrangled data

# %%
#check the decoration
df.columns
# Out:
# Index(['age', 'job', 'marital', 'education', 'default', 'housingLoan',
#        'personalLoan', 'contactMethod', 'lastContact_month', 'lastContact_day',
#        'lastContact_duration', 'numberOfContact', 'pastCam_daysSince',
#        'pastCam_numberOfContact', 'pastCam_result', 'idx_employment',
#        'idx_price', 'idx_confidence', 'idx_euribor', 'idx_employeesNum',
#        'subscribe'],
#       dtype='object')

# %%
np.unique(df['subscribe'])
# Out:
# array([0, 1])

# %%
#invite people for the Kaggle party
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from scipy.stats import norm
from sklearn.preprocessing import StandardScaler
from scipy import stats
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline

# %%
df.columns
# Out:
# Index(['age', 'job', 'marital', 'education', 'default', 'housingLoan',
#        'personalLoan', 'contactMethod', 'lastContact_month', 'lastContact_day',
#        'lastContact_duration', 'numberOfContact', 'pastCam_daysSince',
#        'pastCam_numberOfContact', 'pastCam_result', 'idx_employment',
#        'idx_price', 'idx_confidence', 'idx_euribor', 'idx_employeesNum',
#        'subscribe'],
#       dtype='object')

# %%
fig, ax = plt.subplots()
fig.set_size_inches(16.7, 8.27)
sns.distplot(df.loc[df['subscribe']==0]['numberOfContact']);

# %%
fig, ax = plt.subplots()
fig.set_size_inches(16.7, 8.27)
sns.distplot(df.loc[df['subscribe']==1]['numberOfContact']);

# %%
fig, ax = plt.subplots()
fig.set_size_inches(16.7, 8.27)
sns.distplot(df.loc[df['pastCam_daysSince']<999]['pastCam_daysSince']);

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

la = [24, 28, 31, 34, 38, 40, 41, 42, 43, 44]
lb = [5, 8, 10, 12, 15, 18, 21, 25, 30, 39]
names = ['la', 'lb']
myList = [la] + [lb]
myList

# set fig for boxplots
fig, ax = plt.subplots(sharex=True)
# Add a horizontal grid to the plot
ax.xaxis.grid(True, linestyle='-', which='major', color='lightgrey', alpha=0.5)
ax.set_axisbelow(True)
ax.set_title('Some Title')

for i,l in enumerate(myList):
    ax.boxplot(l, vert=False, positions = [i])
    ax.set_yticklabels([names[i]])

ax.set_ylim(-0.5, len(myList)-0.5)
# Out:
# (-0.5, 1.5)

# %%
df.columns
# Out:
# Index(['age', 'job', 'marital', 'education', 'default', 'housingLoan',
#        'personalLoan', 'contactMethod', 'lastContact_month', 'lastContact_day',
#        'lastContact_duration', 'numberOfContact', 'pastCam_daysSince',
#        'pastCam_numberOfContact', 'pastCam_result', 'idx_employment',
#        'idx_price', 'idx_confidence', 'idx_euribor', 'idx_employeesNum',
#        'subscribe'],
#       dtype='object')

# %%
import pandas as pd
dp=df[['subscribe','lastContact_duration']].boxplot(by='subscribe', figsize=(12,8))
dp.set_ylim([-10,1500
            ])
plt.show()

# %%
fig, ax = plt.subplots()
fig.set_size_inches(16.7, 8.27)
sns.distplot(df.loc[df['subscribe']==1]['age']);

# %%
df.loc[df['lastContact_duration']<250]['subscribe'].sum()/df.loc[df['lastContact_duration']<250]['subscribe'].count()
# Out:
# 0.041537946179327802

# %%
df.loc[df['lastContact_duration']]['subscribe'].sum()/df.loc[df['lastContact_duration']>575]['subscribe'].count()
# Out:
# 0.28161222339304531

# %%
df.loc[df['lastContact_duration']>250]['subscribe'].sum()/df.loc[df['lastContact_duration']>250]['subscribe'].count()
# Out:
# 0.24675233480794889

# %%
df['pastCam_result'].unique()
# Out:
# array(['nonexistent', 'failure', 'success'], dtype=object)

# %%
df.loc[df['pastCam_result']=='success']['subscribe'].sum()/df.loc[df['pastCam_result']=='success']['subscribe'].count()
# Out:
# 0.65112891478514201

# %%
df.loc[df['lastContact_duration']<250]
# Out:
#        age            job   marital            education  default housingLoan  \
# 1       57       services   married          high.school  unknown          no
# 2       37       services   married          high.school       no         yes
# 3       40         admin.   married             basic.6y       no          no
# 5       45       services   married             basic.9y  unknown          no
# 6       59         admin.   married  professional.course       no          no
# 7       41    blue-collar   married              unknown  unknown          no
# 9       25       services    single          high.school       no         yes
# 10      41    blue-collar   married              unknown  unknown          no
# 11      25       services    single          high.school       no         yes
# 12      29    blue-collar    single          high.school       no          no
# 14      35    blue-collar   married             basic.6y       no         yes
# 15      54        retired   married             basic.9y  unknown         yes
# 19      39     management    single             basic.9y  unknown          no
# 20      30     unemployed   married          high.school       no          no
# 23      41     technician    single          high.school       no         yes
# 24      37         admin.   married          high.school       no         yes
# 25      35     technician   married    university.degree       no          no
# 26      59     technician   married              unknown       no         yes
# 27      39  self-employed   married             basic.9y  unknown          no
# 32      49    blue-collar   married              unknown       no          no
# 33      54     management   married             basic.4y  unknown         yes
# 34      54    blue-collar  divorced             basic.4y       no          no
# 39      56     technician   married             basic.4y       no         yes
# 42      38         admin.    single  professional.course       no          no
# 43      57         admin.   married    university.degree       no          no
# 44      44         admin.   married    university.degree  unknown         yes
# 45      42     technician    single  professional.course  unknown          no
# 47      40    blue-collar   married             basic.9y       no          no
# 49      45    blue-collar   married             basic.9y       no         yes
# 50      54         admin.   married          high.school       no          no
# ...    ...            ...       ...                  ...      ...         ...
# 41112   58         admin.   married          high.school       no         yes
# 41113   34     technician   married              unknown       no          no
# 41116   36    blue-collar    single             basic.6y       no          no
# 41118   34     technician   married              unknown       no         yes
# 41124   37     technician    single  professional.course       no         yes
# 41125   37     technician    single  professional.course       no         yes
# 41131   58     management   married    university.degree       no         yes
# 41133   28  self-employed    single    university.degree       no         yes
# 41134   25        student    single          high.school       no          no
# 41135   54     technician   married              unknown       no         yes
# 41136   54     unemployed   married  professional.course       no         yes
# 41139   31       services   married          high.school       no         yes
# 41140   33     management   married    university.degree       no         yes
# 41143   29     technician    single  professional.course       no          no
# 41144   35         admin.    single  professional.course       no         yes
# 41152   26     management    single    university.degree       no         yes
# 41154   41     technician   married  professional.course       no         yes
# 41155   31      housemaid    single    university.degree       no          no
# 41157   31      housemaid    single    university.degree       no          no
# 41167   32         admin.   married    university.degree       no         yes
# 41168   38   entrepreneur   married    university.degree       no          no
# 41169   62       services   married          high.school       no         yes
# 41171   33        student   married  professional.course       no         yes
# 41174   62        retired   married    university.degree       no         yes
# 41175   34        student    single              unknown       no         yes
# 41177   57        retired   married  professional.course       no         yes
# 41179   64        retired  divorced  professional.course       no         yes
# 41182   29     unemployed    single             basic.4y       no         yes
# 41185   56        retired   married    university.degree       no         yes
# 41187   74        retired   married  professional.course       no         yes
#
#       personalLoan contactMethod lastContact_month lastContact_day    ...      \
# 1               no     telephone               may             mon    ...
# 2               no     telephone               may             mon    ...
# 3               no     telephone               may             mon    ...
# 5               no     telephone               may             mon    ...
# 6               no     telephone               may             mon    ...
# 7               no     telephone               may             mon    ...
# 9               no     telephone               may             mon    ...
# 10              no     telephone               may             mon    ...
# 11              no     telephone               may             mon    ...
# 12             yes     telephone               may             mon    ...
# 14              no     telephone               may             mon    ...
# 15             yes     telephone               may             mon    ...
# 19              no     telephone               may             mon    ...
# 20              no     telephone               may             mon    ...
# 23              no     telephone               may             mon    ...
# 24              no     telephone               may             mon    ...
# 25             yes     telephone               may             mon    ...
# 26              no     telephone               may             mon    ...
# 27              no     telephone               may             mon    ...
# 32              no     telephone               may             mon    ...
# 33              no     telephone               may             mon    ...
# 34              no     telephone               may             mon    ...
# 39              no     telephone               may             mon    ...
# 42              no     telephone               may             mon    ...
# 43             yes     telephone               may             mon    ...
# 44              no     telephone               may             mon    ...
# 45              no     telephone               may             mon    ...
# 47             yes     telephone               may             mon    ...
# 49              no     telephone               may             mon    ...
# 50              no     telephone               may             mon    ...
# ...            ...           ...               ...             ...    ...
# 41112           no      cellular               nov             tue    ...
# 41113           no      cellular               nov             tue    ...
# 41116           no      cellular               nov             tue    ...
# 41118           no      cellular               nov             tue    ...
# 41124           no      cellular               nov             wed    ...
# 41125           no      cellular               nov             wed    ...
# 41131           no      cellular               nov             thu    ...
# 41133           no      cellular               nov             thu    ...
# 41134           no      cellular               nov             thu    ...
# 41135           no      cellular               nov             thu    ...
# 41136           no     telephone               nov             thu    ...
# 41139           no      cellular               nov             fri    ...
# 41140           no      cellular               nov             fri    ...
# 41143          yes      cellular               nov             fri    ...
# 41144           no      cellular               nov             fri    ...
# 41152           no      cellular               nov             mon    ...
# 41154           no      cellular               nov             mon    ...
# 41155           no     telephone               nov             mon    ...
# 41157           no      cellular               nov             mon    ...
# 41167           no      cellular               nov             wed    ...
# 41168           no      cellular               nov             wed    ...
# 41169           no      cellular               nov             wed    ...
# 41171           no     telephone               nov             thu    ...
# 41174           no      cellular               nov             thu    ...
# 41175           no      cellular               nov             thu    ...
# 41177           no      cellular               nov             thu    ...
# 41179           no      cellular               nov             fri    ...
# 41182           no      cellular               nov             fri    ...
# 41185           no      cellular               nov             fri    ...
# 41187           no      cellular               nov             fri    ...
#
#        numberOfContact  pastCam_daysSince  pastCam_numberOfContact  \
# 1                    1                999                        0
# 2                    1                999                        0
# 3                    1                999                        0
# 5                    1                999                        0
# 6                    1                999                        0
# 7                    1                999                        0
# 9                    1                999                        0
# 10                   1                999                        0
# 11                   1                999                        0
# 12                   1                999                        0
# 14                   1                999                        0
# 15                   1                999                        0
# 19                   1                999                        0
# 20                   1                999                        0
# 23                   1                999                        0
# 24                   1                999                        0
# 25                   1                999                        0
# 26                   1                999                        0
# 27                   1                999                        0
# 32                   1                999                        0
# 33                   1                999                        0
# 34                   1                999                        0
# 39                   1                999                        0
# 42                   1                999                        0
# 43                   1                999                        0
# 44                   1                999                        0
# 45                   1                999                        0
# 47                   1                999                        0
# 49                   2                999                        0
# 50                   1                999                        0
# ...                ...                ...                      ...
# 41112                1                999                        2
# 41113                1                  6                        2
# 41116                1                999                        0
# 41118                2                999                        2
# 41124                1                  6                        4
# 41125                1                999                        0
# 41131                1                999                        0
# 41133                2                  6                        3
# 41134                1                999                        0
# 41135                1                999                        1
# 41136                2                 10                        4
# 41139                3                999                        0
# 41140                2                999                        0
# 41143                1                  6                        2
# 41144                3                999                        4
# 41152                5                999                        0
# 41154                2                999                        0
# 41155                5                999                        0
# 41157                4                999                        0
# 41167                3                999                        0
# 41168                2                999                        0
# 41169                5                999                        0
# 41171                1                999                        0
# 41174                1                  1                        6
# 41175                1                999                        2
# 41177                6                999                        0
# 41179                3                999                        0
# 41182                1                  9                        1
# 41185                2                999                        0
# 41187                3                999                        1
#
#        pastCam_result idx_employment  idx_price  idx_confidence  idx_euribor  \
# 1         nonexistent            1.1     93.994           -36.4        4.857
# 2         nonexistent            1.1     93.994           -36.4        4.857
# 3         nonexistent            1.1     93.994           -36.4        4.857
# 5         nonexistent            1.1     93.994           -36.4        4.857
# 6         nonexistent            1.1     93.994           -36.4        4.857
# 7         nonexistent            1.1     93.994           -36.4        4.857
# 9         nonexistent            1.1     93.994           -36.4        4.857
# 10        nonexistent            1.1     93.994           -36.4        4.857
# 11        nonexistent            1.1     93.994           -36.4        4.857
# 12        nonexistent            1.1     93.994           -36.4        4.857
# 14        nonexistent            1.1     93.994           -36.4        4.857
# 15        nonexistent            1.1     93.994           -36.4        4.857
# 19        nonexistent            1.1     93.994           -36.4        4.857
# 20        nonexistent            1.1     93.994           -36.4        4.857
# 23        nonexistent            1.1     93.994           -36.4        4.857
# 24        nonexistent            1.1     93.994           -36.4        4.857
# 25        nonexistent            1.1     93.994           -36.4        4.857
# 26        nonexistent            1.1     93.994           -36.4        4.857
# 27        nonexistent            1.1     93.994           -36.4        4.857
# 32        nonexistent            1.1     93.994           -36.4        4.857
# 33        nonexistent            1.1     93.994           -36.4        4.857
# 34        nonexistent            1.1     93.994           -36.4        4.857
# 39        nonexistent            1.1     93.994           -36.4        4.857
# 42        nonexistent            1.1     93.994           -36.4        4.857
# 43        nonexistent            1.1     93.994           -36.4        4.857
# 44        nonexistent            1.1     93.994           -36.4        4.857
# 45        nonexistent            1.1     93.994           -36.4        4.857
# 47        nonexistent            1.1     93.994           -36.4        4.857
# 49        nonexistent            1.1     93.994           -36.4        4.857
# 50        nonexistent            1.1     93.994           -36.4        4.857
# ...               ...            ...        ...             ...          ...
# 41112         failure           -1.1     94.767           -50.8        1.046
# 41113         success           -1.1     94.767           -50.8        1.046
# 41116     nonexistent           -1.1     94.767           -50.8        1.046
# 41118         failure           -1.1     94.767           -50.8        1.046
# 41124         success           -1.1     94.767           -50.8        1.044
# 41125     nonexistent           -1.1     94.767           -50.8        1.044
# 41131     nonexistent           -1.1     94.767           -50.8        1.041
# 41133         success           -1.1     94.767           -50.8        1.041
# 41134     nonexistent           -1.1     94.767           -50.8        1.041
# 41135         failure           -1.1     94.767           -50.8        1.041
# 41136         failure           -1.1     94.767           -50.8        1.041
# 41139     nonexistent           -1.1     94.767           -50.8        1.040
# 41140     nonexistent           -1.1     94.767           -50.8        1.040
# 41143         success           -1.1     94.767           -50.8        1.040
# 41144         failure           -1.1     94.767           -50.8        1.040
# 41152     nonexistent           -1.1     94.767           -50.8        1.039
# 41154     nonexistent           -1.1     94.767           -50.8        1.039
# 41155     nonexistent           -1.1     94.767           -50.8        1.039
# 41157     nonexistent           -1.1     94.767           -50.8        1.039
# 41167     nonexistent           -1.1     94.767           -50.8        1.030
# 41168     nonexistent           -1.1     94.767           -50.8        1.030
# 41169     nonexistent           -1.1     94.767           -50.8        1.030
# 41171     nonexistent           -1.1     94.767           -50.8        1.031
# 41174         success           -1.1     94.767           -50.8        1.031
# 41175         failure           -1.1     94.767           -50.8        1.031
# 41177     nonexistent           -1.1     94.767           -50.8        1.031
# 41179     nonexistent           -1.1     94.767           -50.8        1.028
# 41182         success           -1.1     94.767           -50.8        1.028
# 41185     nonexistent           -1.1     94.767           -50.8        1.028
# 41187         failure           -1.1     94.767           -50.8        1.028
#
#        idx_employeesNum  subscribe
# 1                5191.0          0
# 2                5191.0          0
# 3                5191.0          0
# 5                5191.0          0
# 6                5191.0          0
# 7                5191.0          0
# 9                5191.0          0
# 10               5191.0          0
# 11               5191.0          0
# 12               5191.0          0
# 14               5191.0          0
# 15               5191.0          0
# 19               5191.0          0
# 20               5191.0          0
# 23               5191.0          0
# 24               5191.0          0
# 25               5191.0          0
# 26               5191.0          0
# 27               5191.0          0
# 32               5191.0          0
# 33               5191.0          0
# 34               5191.0          0
# 39               5191.0          0
# 42               5191.0          0
# 43               5191.0          0
# 44               5191.0          0
# 45               5191.0          0
# 47               5191.0          0
# 49               5191.0          0
# 50               5191.0          0
# ...                 ...        ...
# 41112            4963.6          0
# 41113            4963.6          1
# 41116            4963.6          1
# 41118            4963.6          0
# 41124            4963.6          1
# 41125            4963.6          1
# 41131            4963.6          0
# 41133            4963.6          0
# 41134            4963.6          1
# 41135            4963.6          0
# 41136            4963.6          0
# 41139            4963.6          0
# 41140            4963.6          1
# 41143            4963.6          0
# 41144            4963.6          0
# 41152            4963.6          0
# 41154            4963.6          0
# 41155            4963.6          0
# 41157            4963.6          0
# 41167            4963.6          0
# 41168            4963.6          0
# 41169            4963.6          0
# 41171            4963.6          1
# 41174            4963.6          1
# 41175            4963.6          0
# 41177            4963.6          0
# 41179            4963.6          0
# 41182            4963.6          0
# 41185            4963.6          0
# 41187            4963.6          0
#
# [26867 rows x 21 columns]

# %%
df.loc[df['subscribe']==0]['lastContact_duration'].describe()
# Out:
# count    36548.000000
# mean       220.844807
# std        207.096293
# min          0.000000
# 25%         95.000000
# 50%        163.500000
# 75%        279.000000
# max       4918.000000
# Name: lastContact_duration, dtype: float64

# %%
fig, ax = plt.subplots()
fig.set_size_inches(16.7, 8.27)
sns.boxplot(x=df.loc[df['subscribe']==1]['numberOfContact'])

# %%
df.loc[df['pastCam_daysSince']!=999]['pastCam_result'].value_counts()
# Out:
# success    1373
# failure     142
# Name: pastCam_result, dtype: int64

# %%
fig, ax = plt.subplots()
fig.set_size_inches(16.7, 8.27)
sns.distplot(df.loc[df['numberOfContact']>3]['numberOfContact']);

# %%
df.loc[df['subscribe']==0]
# Out:
#        age            job   marital            education  default housingLoan  \
# 0       56      housemaid   married             basic.4y       no          no
# 1       57       services   married          high.school  unknown          no
# 2       37       services   married          high.school       no         yes
# 3       40         admin.   married             basic.6y       no          no
# 4       56       services   married          high.school       no          no
# 5       45       services   married             basic.9y  unknown          no
# 6       59         admin.   married  professional.course       no          no
# 7       41    blue-collar   married              unknown  unknown          no
# 8       24     technician    single  professional.course       no         yes
# 9       25       services    single          high.school       no         yes
# 10      41    blue-collar   married              unknown  unknown          no
# 11      25       services    single          high.school       no         yes
# 12      29    blue-collar    single          high.school       no          no
# 13      57      housemaid  divorced             basic.4y       no         yes
# 14      35    blue-collar   married             basic.6y       no         yes
# 15      54        retired   married             basic.9y  unknown         yes
# 16      35    blue-collar   married             basic.6y       no         yes
# 17      46    blue-collar   married             basic.6y  unknown         yes
# 18      50    blue-collar   married             basic.9y       no         yes
# 19      39     management    single             basic.9y  unknown          no
# 20      30     unemployed   married          high.school       no          no
# 21      55    blue-collar   married             basic.4y  unknown         yes
# 22      55        retired    single          high.school       no         yes
# 23      41     technician    single          high.school       no         yes
# 24      37         admin.   married          high.school       no         yes
# 25      35     technician   married    university.degree       no          no
# 26      59     technician   married              unknown       no         yes
# 27      39  self-employed   married             basic.9y  unknown          no
# 28      54     technician    single    university.degree  unknown          no
# 29      55         admin.   married    university.degree  unknown         yes
# ...    ...            ...       ...                  ...      ...         ...
# 41129   61         admin.   married          high.school       no          no
# 41131   58     management   married    university.degree       no         yes
# 41133   28  self-employed    single    university.degree       no         yes
# 41135   54     technician   married              unknown       no         yes
# 41136   54     unemployed   married  professional.course       no         yes
# 41137   42         admin.   married    university.degree       no         yes
# 41139   31       services   married          high.school       no         yes
# 41143   29     technician    single  professional.course       no          no
# 41144   35         admin.    single  professional.course       no         yes
# 41149   30         admin.    single    university.degree       no         yes
# 41150   41    blue-collar   married             basic.9y       no         yes
# 41152   26     management    single    university.degree       no         yes
# 41154   41     technician   married  professional.course       no         yes
# 41155   31      housemaid    single    university.degree       no          no
# 41157   31      housemaid    single    university.degree       no          no
# 41161   33         admin.   married    university.degree       no         yes
# 41162   60    blue-collar   married             basic.4y       no         yes
# 41167   32         admin.   married    university.degree       no         yes
# 41168   38   entrepreneur   married    university.degree       no          no
# 41169   62       services   married          high.school       no         yes
# 41170   40     management  divorced    university.degree       no         yes
# 41175   34        student    single              unknown       no         yes
# 41176   38      housemaid  divorced          high.school       no         yes
# 41177   57        retired   married  professional.course       no         yes
# 41179   64        retired  divorced  professional.course       no         yes
# 41180   36         admin.   married    university.degree       no          no
# 41182   29     unemployed    single             basic.4y       no         yes
# 41184   46    blue-collar   married  professional.course       no          no
# 41185   56        retired   married    university.degree       no         yes
# 41187   74        retired   married  professional.course       no         yes
#
#       personalLoan contactMethod lastContact_month lastContact_day    ...      \
# 0               no     telephone               may             mon    ...
# 1               no     telephone               may             mon    ...
# 2               no     telephone               may             mon    ...
# 3               no     telephone               may             mon    ...
# 4              yes     telephone               may             mon    ...
# 5               no     telephone               may             mon    ...
# 6               no     telephone               may             mon    ...
# 7               no     telephone               may             mon    ...
# 8               no     telephone               may             mon    ...
# 9               no     telephone               may             mon    ...
# 10              no     telephone               may             mon    ...
# 11              no     telephone               may             mon    ...
# 12             yes     telephone               may             mon    ...
# 13              no     telephone               may             mon    ...
# 14              no     telephone               may             mon    ...
# 15             yes     telephone               may             mon    ...
# 16              no     telephone               may             mon    ...
# 17             yes     telephone               may             mon    ...
# 18             yes     telephone               may             mon    ...
# 19              no     telephone               may             mon    ...
# 20              no     telephone               may             mon    ...
# 21              no     telephone               may             mon    ...
# 22              no     telephone               may             mon    ...
# 23              no     telephone               may             mon    ...
# 24              no     telephone               may             mon    ...
# 25             yes     telephone               may             mon    ...
# 26              no     telephone               may             mon    ...
# 27              no     telephone               may             mon    ...
# 28              no     telephone               may             mon    ...
# 29              no     telephone               may             mon    ...
# ...            ...           ...               ...             ...    ...
# 41129           no     telephone               nov             wed    ...
# 41131           no      cellular               nov             thu    ...
# 41133           no      cellular               nov             thu    ...
# 41135           no      cellular               nov             thu    ...
# 41136           no     telephone               nov             thu    ...
# 41137           no      cellular               nov             thu    ...
# 41139           no      cellular               nov             fri    ...
# 41143          yes      cellular               nov             fri    ...
# 41144           no      cellular               nov             fri    ...
# 41149           no      cellular               nov             mon    ...
# 41150           no      cellular               nov             mon    ...
# 41152           no      cellular               nov             mon    ...
# 41154           no      cellular               nov             mon    ...
# 41155           no     telephone               nov             mon    ...
# 41157           no      cellular               nov             mon    ...
# 41161           no      cellular               nov             tue    ...
# 41162           no      cellular               nov             tue    ...
# 41167           no      cellular               nov             wed    ...
# 41168           no      cellular               nov             wed    ...
# 41169           no      cellular               nov             wed    ...
# 41170           no      cellular               nov             wed    ...
# 41175           no      cellular               nov             thu    ...
# 41176          yes      cellular               nov             thu    ...
# 41177           no      cellular               nov             thu    ...
# 41179           no      cellular               nov             fri    ...
# 41180           no      cellular               nov             fri    ...
# 41182           no      cellular               nov             fri    ...
# 41184           no      cellular               nov             fri    ...
# 41185           no      cellular               nov             fri    ...
# 41187           no      cellular               nov             fri    ...
#
#        numberOfContact  pastCam_daysSince  pastCam_numberOfContact  \
# 0                    1                999                        0
# 1                    1                999                        0
# 2                    1                999                        0
# 3                    1                999                        0
# 4                    1                999                        0
# 5                    1                999                        0
# 6                    1                999                        0
# 7                    1                999                        0
# 8                    1                999                        0
# 9                    1                999                        0
# 10                   1                999                        0
# 11                   1                999                        0
# 12                   1                999                        0
# 13                   1                999                        0
# 14                   1                999                        0
# 15                   1                999                        0
# 16                   1                999                        0
# 17                   1                999                        0
# 18                   1                999                        0
# 19                   1                999                        0
# 20                   1                999                        0
# 21                   1                999                        0
# 22                   1                999                        0
# 23                   1                999                        0
# 24                   1                999                        0
# 25                   1                999                        0
# 26                   1                999                        0
# 27                   1                999                        0
# 28                   2                999                        0
# 29                   1                999                        0
# ...                ...                ...                      ...
# 41129                4                999                        0
# 41131                1                999                        0
# 41133                2                  6                        3
# 41135                1                999                        1
# 41136                2                 10                        4
# 41137                3                999                        1
# 41139                3                999                        0
# 41143                1                  6                        2
# 41144                3                999                        4
# 41149                2                999                        0
# 41150                2                999                        1
# 41152                5                999                        0
# 41154                2                999                        0
# 41155                5                999                        0
# 41157                4                999                        0
# 41161                1                999                        1
# 41162                2                  4                        1
# 41167                3                999                        0
# 41168                2                999                        0
# 41169                5                999                        0
# 41170                2                999                        4
# 41175                1                999                        2
# 41176                1                999                        0
# 41177                6                999                        0
# 41179                3                999                        0
# 41180                2                999                        0
# 41182                1                  9                        1
# 41184                1                999                        0
# 41185                2                999                        0
# 41187                3                999                        1
#
#        pastCam_result idx_employment  idx_price  idx_confidence  idx_euribor  \
# 0         nonexistent            1.1     93.994           -36.4        4.857
# 1         nonexistent            1.1     93.994           -36.4        4.857
# 2         nonexistent            1.1     93.994           -36.4        4.857
# 3         nonexistent            1.1     93.994           -36.4        4.857
# 4         nonexistent            1.1     93.994           -36.4        4.857
# 5         nonexistent            1.1     93.994           -36.4        4.857
# 6         nonexistent            1.1     93.994           -36.4        4.857
# 7         nonexistent            1.1     93.994           -36.4        4.857
# 8         nonexistent            1.1     93.994           -36.4        4.857
# 9         nonexistent            1.1     93.994           -36.4        4.857
# 10        nonexistent            1.1     93.994           -36.4        4.857
# 11        nonexistent            1.1     93.994           -36.4        4.857
# 12        nonexistent            1.1     93.994           -36.4        4.857
# 13        nonexistent            1.1     93.994           -36.4        4.857
# 14        nonexistent            1.1     93.994           -36.4        4.857
# 15        nonexistent            1.1     93.994           -36.4        4.857
# 16        nonexistent            1.1     93.994           -36.4        4.857
# 17        nonexistent            1.1     93.994           -36.4        4.857
# 18        nonexistent            1.1     93.994           -36.4        4.857
# 19        nonexistent            1.1     93.994           -36.4        4.857
# 20        nonexistent            1.1     93.994           -36.4        4.857
# 21        nonexistent            1.1     93.994           -36.4        4.857
# 22        nonexistent            1.1     93.994           -36.4        4.857
# 23        nonexistent            1.1     93.994           -36.4        4.857
# 24        nonexistent            1.1     93.994           -36.4        4.857
# 25        nonexistent            1.1     93.994           -36.4        4.857
# 26        nonexistent            1.1     93.994           -36.4        4.857
# 27        nonexistent            1.1     93.994           -36.4        4.857
# 28        nonexistent            1.1     93.994           -36.4        4.857
# 29        nonexistent            1.1     93.994           -36.4        4.857
# ...               ...            ...        ...             ...          ...
# 41129     nonexistent           -1.1     94.767           -50.8        1.044
# 41131     nonexistent           -1.1     94.767           -50.8        1.041
# 41133         success           -1.1     94.767           -50.8        1.041
# 41135         failure           -1.1     94.767           -50.8        1.041
# 41136         failure           -1.1     94.767           -50.8        1.041
# 41137         failure           -1.1     94.767           -50.8        1.041
# 41139     nonexistent           -1.1     94.767           -50.8        1.040
# 41143         success           -1.1     94.767           -50.8        1.040
# 41144         failure           -1.1     94.767           -50.8        1.040
# 41149     nonexistent           -1.1     94.767           -50.8        1.039
# 41150         failure           -1.1     94.767           -50.8        1.039
# 41152     nonexistent           -1.1     94.767           -50.8        1.039
# 41154     nonexistent           -1.1     94.767           -50.8        1.039
# 41155     nonexistent           -1.1     94.767           -50.8        1.039
# 41157     nonexistent           -1.1     94.767           -50.8        1.039
# 41161         failure           -1.1     94.767           -50.8        1.035
# 41162         success           -1.1     94.767           -50.8        1.035
# 41167     nonexistent           -1.1     94.767           -50.8        1.030
# 41168     nonexistent           -1.1     94.767           -50.8        1.030
# 41169     nonexistent           -1.1     94.767           -50.8        1.030
# 41170         failure           -1.1     94.767           -50.8        1.030
# 41175         failure           -1.1     94.767           -50.8        1.031
# 41176     nonexistent           -1.1     94.767           -50.8        1.031
# 41177     nonexistent           -1.1     94.767           -50.8        1.031
# 41179     nonexistent           -1.1     94.767           -50.8        1.028
# 41180     nonexistent           -1.1     94.767           -50.8        1.028
# 41182         success           -1.1     94.767           -50.8        1.028
# 41184     nonexistent           -1.1     94.767           -50.8        1.028
# 41185     nonexistent           -1.1     94.767           -50.8        1.028
# 41187         failure           -1.1     94.767           -50.8        1.028
#
#        idx_employeesNum  subscribe
# 0                5191.0          0
# 1                5191.0          0
# 2                5191.0          0
# 3                5191.0          0
# 4                5191.0          0
# 5                5191.0          0
# 6                5191.0          0
# 7                5191.0          0
# 8                5191.0          0
# 9                5191.0          0
# 10               5191.0          0
# 11               5191.0          0
# 12               5191.0          0
# 13               5191.0          0
# 14               5191.0          0
# 15               5191.0          0
# 16               5191.0          0
# 17               5191.0          0
# 18               5191.0          0
# 19               5191.0          0
# 20               5191.0          0
# 21               5191.0          0
# 22               5191.0          0
# 23               5191.0          0
# 24               5191.0          0
# 25               5191.0          0
# 26               5191.0          0
# 27               5191.0          0
# 28               5191.0          0
# 29               5191.0          0
# ...                 ...        ...
# 41129            4963.6          0
# 41131            4963.6          0
# 41133            4963.6          0
# 41135            4963.6          0
# 41136            4963.6          0
# 41137            4963.6          0
# 41139            4963.6          0
# 41143            4963.6          0
# 41144            4963.6          0
# 41149            4963.6          0
# 41150            4963.6          0
# 41152            4963.6          0
# 41154            4963.6          0
# 41155            4963.6          0
# 41157            4963.6          0
# 41161            4963.6          0
# 41162            4963.6          0
# 41167            4963.6          0
# 41168            4963.6          0
# 41169            4963.6          0
# 41170            4963.6          0
# 41175            4963.6          0
# 41176            4963.6          0
# 41177            4963.6          0
# 41179            4963.6          0
# 41180            4963.6          0
# 41182            4963.6          0
# 41184            4963.6          0
# 41185            4963.6          0
# 41187            4963.6          0
#
# [36548 rows x 21 columns]

# %%
np.std(df['age'])
# Out:
# 10.421123471838916

# %%
#skewness and kurtosis
print("Skewness: %f" % df['numberOfContact'].skew())
print("Kurtosis: %f" % df['numberOfContact'].kurt())
# Out:
# Skewness: 4.762507
# Kurtosis: 36.979795

# %%
df['job'].value_counts()
# Out:
# admin.           10752
# blue-collar       9254
# technician        6743
# services          3969
# management        2924
# retired           1720
# entrepreneur      1456
# self-employed     1421
# housemaid         1060
# unemployed        1014
# student            875
# Name: job, dtype: int64

# %%
admin
blue-collar
technician
services
management
retired+housemaid+unemployed+student+unemployed
entrepreenur+self_employed

# %%
#histogram and normal probability plot
sns.distplot(df['numberOfContact'], fit=norm);
fig = plt.figure()
res = stats.probplot(df['numberOfContact'], plot=plt)

# %%
#transform data
df.loc[df['subscribe']==0,'numberOfContact'] = np.log(df['numberOfContact'])

# %%
#correlation matrix
corrmat = df.corr()
f, ax = plt.subplots(figsize=(12, 9))
sns.heatmap(corrmat, vmax=.8, square=True);

# %%
#saleprice correlation matrix
corrmat = df.corr()
k = 10 #number of variables for heatmap
cols = corrmat.nlargest(k, 'subscribe')['subscribe'].index
cm = np.corrcoef(df[cols].values.T)
sns.set(font_scale=1.25)
hm = sns.heatmap(cm, cbar=True, annot=True, square=True, fmt='.2f', annot_kws={'size': 10}, yticklabels=cols.values, xticklabels=cols.values)
plt.show()

# %%
df.columns
# Out:
# Index(['age', 'job', 'marital', 'education', 'default', 'housingLoan',
#        'personalLoan', 'contactMethod', 'lastContact_month', 'lastContact_day',
#        'lastContact_duration', 'numberOfContact', 'pastCam_daysSince',
#        'pastCam_numberOfContact', 'pastCam_result', 'idx_employment',
#        'idx_price', 'idx_confidence', 'idx_euribor', 'idx_employeesNum',
#        'subscribe'],
#       dtype='object')

# %%
#scatterplot
sns.set()
cols = ['age',  'numberOfContact','pastCam_numberOfContact','pastCam_daysSince','lastContact_duration']
sns.pairplot(df[cols], size = 2.5)
plt.show();

# %%
#scatterplot
sns.set()
cols = ['idx_employment','idx_price', 'idx_confidence', 'idx_euribor', 'idx_employeesNum']
sns.pairplot(df[cols], size = 2.5)
plt.show();

# %%
fig, ax = plt.subplots()
fig.set_size_inches(16.7, 8.27)
sns.distplot(df['age']);
